# %%
import numpy as np
import random
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text \
    import text_to_word_sequence
from tensorflow.keras.preprocessing.sequence \
    import pad_sequences
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
# Constants
EPOCHS = 20
BATCH_SIZE = 128
MAX_WORDS = 10000
READ_LINES = 60000
LAYER_SIZE = 256
EMBEDDING_WIDTH = 128
TEST_PERCENT = 0.2
SAMPLE_SIZE = 20
OOV_WORD = 'UNK'
PAD_INDEX = 0
OOV_INDEX = 1
START_INDEX = MAX_WORDS - 2
STOP_INDEX = MAX_WORDS - 1
MAX_LENGTH = 60
SRC_DEST_FILE_NAME = '/content/eng-fra.txt'

# %%
# Function to read file.
def read_file_combined(file_name, max_len):
    file = open(file_name, 'r', encoding='utf-8')
    src_word_sequences = []
    dest_word_sequences = []
    for i, line in enumerate(file):
        if i == READ_LINES:
            break
        pair = line.split('\t')
        word_sequence = text_to_word_sequence(pair[1])
        src_word_sequence = word_sequence[0:max_len]
        src_word_sequences.append(src_word_sequence)
        word_sequence = text_to_word_sequence(pair[0])
        dest_word_sequence = word_sequence[0:max_len]
        dest_word_sequences.append(dest_word_sequence)
    file.close()
    return src_word_sequences, dest_word_sequences

# %%
# Functions to tokenize and un-tokenize sequences.
def tokenize(sequences):
    # "MAX_WORDS-2" used to reserve two indices
    # for START and STOP.
    tokenizer = Tokenizer(num_words=MAX_WORDS-2,
                          oov_token=OOV_WORD)
    tokenizer.fit_on_texts(sequences)
    token_sequences = tokenizer.texts_to_sequences(sequences)
    return tokenizer, token_sequences

def tokens_to_words(tokenizer, seq):
    word_seq = []
    for index in seq:
        if index == PAD_INDEX:
            word_seq.append('PAD')
        elif index == OOV_INDEX:
            word_seq.append(OOV_WORD)
        elif index == START_INDEX:
            word_seq.append('START')
        elif index == STOP_INDEX:
            word_seq.append('STOP')
        else:
            word_seq.append(tokenizer.sequences_to_texts(
                [[index]])[0])
    print(word_seq)

# %%
# Read file and tokenize.
src_seq, dest_seq = read_file_combined(SRC_DEST_FILE_NAME,
                                       MAX_LENGTH)
src_tokenizer, src_token_seq = tokenize(src_seq)
dest_tokenizer, dest_token_seq = tokenize(dest_seq)

# %%
# Prepare training data.
dest_target_token_seq = [x + [STOP_INDEX] for x in dest_token_seq]
dest_input_token_seq = [[START_INDEX] + x for x in
                        dest_target_token_seq]
src_input_data = pad_sequences(src_token_seq, padding='post')
dest_input_data = pad_sequences(dest_input_token_seq,
                                padding='post')
dest_target_data = pad_sequences(
    dest_target_token_seq, padding='post', maxlen
    = len(dest_input_data[0]))

# %%
# Split into training and test set.
rows = len(src_input_data[:,0])
all_indices = list(range(rows))
test_rows = int(rows * TEST_PERCENT)
test_indices = random.sample(all_indices, test_rows)
train_indices = [x for x in all_indices if x not in test_indices]

train_src_input_data = src_input_data[train_indices]
train_dest_input_data = dest_input_data[train_indices]
train_dest_target_data = dest_target_data[train_indices]

test_src_input_data = src_input_data[test_indices]
test_dest_input_data = dest_input_data[test_indices]
test_dest_target_data = dest_target_data[test_indices]

# Create a sample of the test set that we will inspect in detail.
test_indices = list(range(test_rows))
sample_indices = random.sample(test_indices, SAMPLE_SIZE)
sample_input_data = test_src_input_data[sample_indices]
sample_target_data = test_dest_target_data[sample_indices]

# %%
# Build encoder model.
# Input is input sequence in source language.
enc_embedding_input = Input(shape=(None, ))

# Create the encoder layers.
enc_embedding_layer = Embedding(
    output_dim=EMBEDDING_WIDTH, input_dim
    = MAX_WORDS, mask_zero=True)
enc_layer1 = LSTM(LAYER_SIZE, return_state=True,
                  return_sequences=True)
enc_layer2 = LSTM(LAYER_SIZE, return_state=True)

# Connect the encoder layers.
# We don't use the last layer output, only the state.
enc_embedding_layer_outputs = \
    enc_embedding_layer(enc_embedding_input)
enc_layer1_outputs, enc_layer1_state_h, enc_layer1_state_c = \
    enc_layer1(enc_embedding_layer_outputs)
_, enc_layer2_state_h, enc_layer2_state_c = \
    enc_layer2(enc_layer1_outputs)

# Build the model.
enc_model = Model(enc_embedding_input,
                  [enc_layer1_state_h, enc_layer1_state_c,
                   enc_layer2_state_h, enc_layer2_state_c])
enc_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, None, 128) │  1,280,000 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, None)      │          0 │ input_layer[0][0] │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, None,     │    394,240 │ embedding[0][0],  │
# │                     │ 256), (None,      │            │ not_equal[0][0]   │
# │                     │ 256), (None,      │            │                   │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 256),     │    525,312 │ lstm[0][0],       │
# │                     │ (None, 256),      │            │ not_equal[0][0]   │
# │                     │ (None, 256)]      │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,199,552 (8.39 MB)
#  Trainable params: 2,199,552 (8.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Build decoder model.
# Input to the network is input sequence in destination
# language and intermediate state.
dec_layer1_state_input_h = Input(shape=(LAYER_SIZE,))
dec_layer1_state_input_c = Input(shape=(LAYER_SIZE,))
dec_layer2_state_input_h = Input(shape=(LAYER_SIZE,))
dec_layer2_state_input_c = Input(shape=(LAYER_SIZE,))
dec_embedding_input = Input(shape=(None, ))

# Create the decoder layers.
dec_embedding_layer = Embedding(output_dim=EMBEDDING_WIDTH,
                                input_dim=MAX_WORDS,
                                mask_zero=True)
dec_layer1 = LSTM(LAYER_SIZE, return_state = True,
                  return_sequences=True)
dec_layer2 = LSTM(LAYER_SIZE, return_state = True,
                  return_sequences=True)
dec_layer3 = Dense(MAX_WORDS, activation='softmax')

# Connect the decoder layers.
dec_embedding_layer_outputs = dec_embedding_layer(
    dec_embedding_input)
dec_layer1_outputs, dec_layer1_state_h, dec_layer1_state_c = \
    dec_layer1(dec_embedding_layer_outputs,
    initial_state=[dec_layer1_state_input_h,
                   dec_layer1_state_input_c])
dec_layer2_outputs, dec_layer2_state_h, dec_layer2_state_c = \
    dec_layer2(dec_layer1_outputs,
    initial_state=[dec_layer2_state_input_h,
                   dec_layer2_state_input_c])
dec_layer3_outputs = dec_layer3(dec_layer2_outputs)

# Build the model.
dec_model = Model([dec_embedding_input,
                   dec_layer1_state_input_h,
                   dec_layer1_state_input_c,
                   dec_layer2_state_input_h,
                   dec_layer2_state_input_c],
                  [dec_layer3_outputs, dec_layer1_state_h,
                   dec_layer1_state_c, dec_layer2_state_h,
                   dec_layer2_state_c])
dec_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 128) │  1,280,000 │ input_layer_5[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 256)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 256)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, None,     │    394,240 │ embedding_1[0][0… │
# │                     │ 256), (None,      │            │ input_layer_1[0]… │
# │                     │ 256), (None,      │            │ input_layer_2[0]… │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 256)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_4       │ (None, 256)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    525,312 │ lstm_2[0][0],     │
# │                     │ 256), (None,      │            │ input_layer_3[0]… │
# │                     │ 256), (None,      │            │ input_layer_4[0]… │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, None,      │  2,570,000 │ lstm_3[0][0]      │
# │                     │ 10000)            │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,769,552 (18.19 MB)
#  Trainable params: 4,769,552 (18.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Build and compile full training model.
# We do not use the state output when training.
train_enc_embedding_input = Input(shape=(None, ))
train_dec_embedding_input = Input(shape=(None, ))
intermediate_state = enc_model(train_enc_embedding_input)
train_dec_output, _, _, _, _ = dec_model(
    [train_dec_embedding_input] +
    intermediate_state)
training_model = Model([train_enc_embedding_input,
                        train_dec_embedding_input],
                        train_dec_output)
optimizer = RMSprop(learning_rate=0.01)
training_model.compile(loss='sparse_categorical_crossentropy',
                       optimizer=optimizer, metrics =['accuracy'])
training_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_7       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional          │ [(None, 256),     │  2,199,552 │ input_layer_6[0]… │
# │ (Functional)        │ (None, 256),      │            │                   │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ [(None, None,     │  4,769,552 │ input_layer_7[0]… │
# │ (Functional)        │ 10000), (None,    │            │ functional[0][0], │
# │                     │ 256), (None,      │            │ functional[0][1], │
# │                     │ 256), (None,      │            │ functional[0][2], │
# │                     │ 256), (None,      │            │ functional[0][3]  │
# │                     │ 256)]             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,969,104 (26.59 MB)
#  Trainable params: 6,969,104 (26.59 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train and test repeatedly.
for i in range(EPOCHS):
    print('step: ' , i)
    # Train model for one epoch.
    history = training_model.fit(
        [train_src_input_data, train_dest_input_data],
        train_dest_target_data, validation_data=(
            [test_src_input_data, test_dest_input_data],
            test_dest_target_data), batch_size=BATCH_SIZE,
        epochs=1)

    # Loop through samples to see result
    for (test_input, test_target) in zip(sample_input_data,
                                         sample_target_data):
        # Run a single sentence through encoder model.
        x = np.reshape(test_input, (1, -1))
        last_states = enc_model.predict(
            x, verbose=0)
        # Provide resulting state and START_INDEX as input
        # to decoder model.
        prev_word_index = START_INDEX
        produced_string = ''
        pred_seq = []
        for j in range(MAX_LENGTH):
            x = np.reshape(np.array(prev_word_index), (1, 1))
            # Predict next word and capture internal state.
            preds, dec_layer1_state_h, dec_layer1_state_c, \
                dec_layer2_state_h, dec_layer2_state_c = \
                    dec_model.predict(
                        [x] + last_states, verbose=0)
            last_states = [dec_layer1_state_h,
                           dec_layer1_state_c,
                           dec_layer2_state_h,
                           dec_layer2_state_c]
            # Find the most probable word.
            prev_word_index = np.asarray(preds[0][0]).argmax()
            pred_seq.append(prev_word_index)
            if prev_word_index == STOP_INDEX:
                break
        tokens_to_words(src_tokenizer, test_input)
        tokens_to_words(dest_tokenizer, test_target)
        tokens_to_words(dest_tokenizer, pred_seq)
        print('\n\n')
# Out:
# step:  0
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1223s 3s/step - accuracy: 0.2868 - loss: 4.5837 - val_accuracy: 0.3089 - val_loss: 3.0345
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', "don't", 'have', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'have', 'the', 'good', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['the', 'house', 'is', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['it', 'is', 'not', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['it', 'is', 'the', 'house', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'have', 'to', 'be', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'a', 'house', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'is', 'a', 'house', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'a', 'house', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'one', 'are', 'the', 'good', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'all', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'like', 'the', 'good', 'house', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'him', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['the', 'house', 'is', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'is', 'a', 'good', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'to', 'be', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'thought', 'you', 'were', 'you', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'does', 'me', 'do', 'this', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'ready', 'to', 'do', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'is', 'the', 'good', 'STOP']
#
#
#
# step:  1
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1220s 3s/step - accuracy: 0.3273 - loss: 2.7879 - val_accuracy: 0.3659 - val_loss: 2.3517
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'be', 'going', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'to', 'play', 'the', 'day', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['your', 'nice', 'is', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'all', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'all', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'get', 'to', 'die', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'nice', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'lost', 'his', 'book', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'room', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'all', 'all', 'us', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'all', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'was', 'in', 'the', 'same', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'hate', 'that', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['the', 'father', 'is', 'bad', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'book', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'tired', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'what', 'you', 'can', 'do', 'it', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'does', 'it', 'do', 'it', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'ready', 'to', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'is', 'the', 'door', 'every', 'them', 'STOP']
#
#
#
# step:  2
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1220s 3s/step - accuracy: 0.3824 - loss: 2.0990 - val_accuracy: 0.4054 - val_loss: 1.9155
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'be', 'alone', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'to', 'study', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['the', 'good', 'is', 'good', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'for', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'all', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'tell', 'me', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'time', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'has', 'his', 'money', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["that's", 'my', 'house', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'dead', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'had', 'to', 'play', 'in', 'the', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'hate', 'it', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['my', 'wife', 'is', 'a', 'doctor', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'doctor', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'surprised', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'what', 'you', 'can', 'do', 'it', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'does', 'it', 'happen', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['do', 'you', 'have', 'a', 'new', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'has', 'both', 'both', 'STOP']
#
#
#
# step:  3
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1226s 3s/step - accuracy: 0.4266 - loss: 1.6171 - val_accuracy: 0.4317 - val_loss: 1.6590
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'prefer', 'to', 'study', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'carefully', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'for', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'right', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'hurt', 'me', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'time', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'is', 'working', 'at', 'his', 'job', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'fault', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', "one's", 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'mad', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'ate', 'to', 'play', 'every', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'hate', 'this', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['the', 'daughter', 'is', 'possible', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'cake', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'so', 'confused', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'what', 'you', 'can', 'do', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'he', 'doing', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'kept', 'our', 'door', 'STOP']
#
#
#
# step:  4
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1221s 3s/step - accuracy: 0.4641 - loss: 1.2432 - val_accuracy: 0.4515 - val_loss: 1.4797
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'study', 'french', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'weather', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'really', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'there', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'hurt', 'me', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'drinks', 'his', 'coffee', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'school', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', "one's", 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'mad', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'ran', 'up', 'the', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'this', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['the', 'family', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'letter', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'confused', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'what', 'you', 'can', 'need', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'from', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'worked', 'all', 'day', 'STOP']
#
#
#
# step:  5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1223s 3s/step - accuracy: 0.4945 - loss: 0.9782 - val_accuracy: 0.4643 - val_loss: 1.3777
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'live', 'french', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'morning', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'for', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['it', 'is', 'getting', 'fun', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'pay', 'to', 'apologize', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'ignored', 'his', 'coffee', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'table', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'one', 'is', 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'gone', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'paid', 'to', 'work', 'by', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'that', 'so', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["tom's", 'family', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'call', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'does', 'it', 'happen', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'stayed', 'all', 'the', 'windows', 'STOP']
#
#
#
# step:  6
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1223s 3s/step - accuracy: 0.5167 - loss: 0.7805 - val_accuracy: 0.4717 - val_loss: 1.3204
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'ought', 'to', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'prefer', 'to', 'like', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'morning', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'for', 'you', 'to', 'love', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'done', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'always', 'call', 'me', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'waste', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'ignored', 'his', 'coffee', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'school', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', "one's", 'all', 'yours', 'for', 'you', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'gone', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'ran', 'up', 'the', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'this', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["tom's", 'family', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'letter', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'he', 'doing', 'there', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'ignored', 'the', 'windows', 'STOP']
#
#
#
# step:  7
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1226s 3s/step - accuracy: 0.5364 - loss: 0.6191 - val_accuracy: 0.4771 - val_loss: 1.2841
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'would', 'like', 'to', 'study', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['enjoy', 'your', 'reason', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'great', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'getting', 'time', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'always', 'do', 'too', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'lovely', 'day', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'school', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', "one's", 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'gone', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'the', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'this', 'so', 'much', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["tom's", 'family', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'present', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'you', "can't", 'know', 'you', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'train', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'ignored', 'our', 'kids', 'STOP']
#
#
#
# step:  8
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1221s 3s/step - accuracy: 0.5506 - loss: 0.5052 - val_accuracy: 0.4823 - val_loss: 1.2716
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'would', 'like', 'to', 'study', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'your', 'good', 'is', 'right', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'good', 'for', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'all', 'right', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'always', 'apologize', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'time', 'we', 'are', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'unfolded', 'his', 'coffee', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'school', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'one', 'is', 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'waited', 'on', 'the', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'this', 'one', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['the', 'family', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'handed', 'him', 'a', 'pencil', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'does', 'it', 'end', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'left', 'away', 'the', 'windows', 'STOP']
#
#
#
# step:  9
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1215s 3s/step - accuracy: 0.5620 - loss: 0.4145 - val_accuracy: 0.4858 - val_loss: 1.2688
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'would', 'study', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'timing', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'time', 'is', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'hurt', 'me', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'lowered', 'his', 'coffee', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'school', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'one', 'is', 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'gone', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'waited', 'to', 'the', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'this', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['the', 'family', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'phone', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'rude', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'doing', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'threatening', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'stuck', 'all', 'the', 'windows', 'STOP']
#
#
#
# step:  10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1215s 3s/step - accuracy: 0.5748 - loss: 0.3378 - val_accuracy: 0.4882 - val_loss: 1.2844
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'ought', 'to', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'to', 'study', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'is', 'good', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'time', 'is', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'always', 'call', 'me', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'lovely', 'day', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'buttoned', 'his', 'coffee', 'STOP']
#
#
#
# ...
# ['they', 'left', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'waited', 'to', 'bring', 'the', 'light', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'her', 'so', 'much', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['it', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'her', 'a', 'towel', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'it', 'happening', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'walked', 'away', 'STOP']
#
#
#
# step:  17
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1257s 3s/step - accuracy: 0.6056 - loss: 0.1368 - val_accuracy: 0.4953 - val_loss: 1.3747
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'ought', 'to', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'to', 'study', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'of', 'tea', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['there', 'are', 'you', 'there', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'always', 'tells', 'me', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'room', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'one', 'is', 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'gone', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'the', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'that', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'present', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'that', 'crying', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'looked', 'in', 'love', 'STOP']
#
#
#
# step:  18
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1314s 4s/step - accuracy: 0.6074 - loss: 0.1278 - val_accuracy: 0.4950 - val_loss: 1.3936
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'ought', 'to', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'want', 'to', 'study', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'of', 'good', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'part', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', "didn't", 'hurt', 'me', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'lovely', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'school', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', "one's", 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'gone', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'waited', 'down', 'the', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'this', 'so', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['the', 'idea', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'present', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'that', 'happening', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'showed', 'away', 'STOP']
#
#
#
# step:  19
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1317s 4s/step - accuracy: 0.6087 - loss: 0.1201 - val_accuracy: 0.4964 - val_loss: 1.4006
# ['nous', 'devrions', 'faire', 'mieux', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'should', 'do', 'better', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['we', 'ought', 'to', 'do', 'better', 'STOP']
#
#
#
# ['je', 'voudrais', 'étudier', 'le', 'français', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["i'd", 'like', 'to', 'study', 'french', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'love', 'to', 'study', 'french', 'STOP']
#
#
#
# ['bonne', 'année', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['happy', 'new', 'year', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['good', 'is', 'good', 'STOP']
#
#
#
# ['ce', "n'est", 'pas', 'sain', 'pour', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'for', 'you', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'not', 'healthy', 'to', 'you', 'STOP']
#
#
#
# ['ça', 'y', 'est', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'it', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["it's", 'all', 'a', 'deal', 'STOP']
#
#
#
# ['tom', 'ne', "m'a", 'toujours', 'pas', 'payé', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'still', "hasn't", 'paid', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'always', 'always', 'listen', 'to', 'me', 'STOP']
#
#
#
# ['quelle', 'journée', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'day', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['what', 'a', 'lovely', 'STOP']
#
#
#
# ['tom', 'UNK', 'son', 'café', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['tom', 'sipped', 'his', 'coffee', 'STOP']
#
#
#
# ["c'est", 'mon', 'école', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'is', 'my', 'school', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'my', 'school', 'STOP']
#
#
#
# ['celui', 'ci', 'est', 'tout', 'à', 'vous', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['that', 'one', 'is', 'all', 'yours', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', "one's", 'all', 'yours', 'STOP']
#
#
#
# ['elles', 'sont', 'parties', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['they', 'left', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ["they're", 'gone', 'STOP']
#
#
#
# ["j'ai", 'attendu', 'UNK', 'du', 'bus', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'waited', 'for', 'a', 'bus', 'to', 'come', 'STOP', 'PAD', 'PAD']
# ['i', 'waited', 'by', 'bus', 'STOP']
#
#
#
# ['je', "l'aime", 'ainsi', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'it', 'that', 'way', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'like', 'this', 'so', 'much', 'STOP']
#
#
#
# ['la', 'famille', "c'est", 'important', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['family', 'is', 'important', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['this', 'is', 'important', 'STOP']
#
#
#
# ['elle', 'lui', 'donna', 'un', 'chandail', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'sweater', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['she', 'gave', 'him', 'a', 'present', 'STOP']
#
#
#
# ["j'étais", 'tellement', 'déçu', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'was', 'so', 'disappointed', 'STOP']
#
#
#
# ['je', 'sais', 'précisément', 'ce', 'dont', 'vous', 'avez', 'besoin', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP', 'PAD', 'PAD', 'PAD']
# ['i', 'know', 'just', 'what', 'you', 'need', 'STOP']
#
#
#
# ['pourquoi', 'cela', 'arrive', 't', 'il', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'happening', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['why', 'is', 'this', 'crying', 'STOP']
#
#
#
# ['es', 'tu', 'en', 'train', 'de', 'me', 'draguer', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'me', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['are', 'you', 'flirting', 'with', 'him', 'STOP']
#
#
#
# ['il', 'a', 'résolu', 'tous', 'les', 'problèmes', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'solved', 'all', 'the', 'problems', 'STOP', 'PAD', 'PAD', 'PAD', 'PAD']
# ['he', 'walked', 'all', 'the', 'windows', 'STOP']
